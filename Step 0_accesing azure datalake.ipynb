# %%
pip install azure-storage-file-datalake pandas pyarrow openpyxl xlrd  matplotlib  python-dotenv
# Out:
# Requirement already satisfied: azure-storage-file-datalake in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (12.15.0)
# Requirement already satisfied: pandas in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: pyarrow in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (16.1.0)
# Requirement already satisfied: openpyxl in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (3.1.5)
# Requirement already satisfied: xlrd in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (3.9.0)
# Requirement already satisfied: python-dotenv in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: azure-core>=1.28.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-storage-file-datalake) (1.30.2)
# Requirement already satisfied: azure-storage-blob>=12.20.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-storage-file-datalake) (12.20.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-storage-file-datalake) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-storage-file-datalake) (0.6.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-core>=1.28.0->azure-storage-file-datalake) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-core>=1.28.0->azure-storage-file-datalake) (1.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from azure-storage-blob>=12.20.0->azure-storage-file-datalake) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.20.0->azure-storage-file-datalake) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-file-datalake) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-file-datalake) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-file-datalake) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-file-datalake) (2024.6.2)
# Requirement already satisfied: pycparser in c:\users\hp\onedrive\documents\eduardo toledo\asai\graph_customer_segmentation\.venv\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.20.0->azure-storage-file-datalake) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.storage.filedatalake import DataLakeServiceClient
import pandas as pd
import os
from io import BytesIO
from dotenv import load_dotenv
from pathlib import Path

load_dotenv()


# Access the environment variables
account_name = os.getenv('ACCOUNT_NAME')
container = os.getenv('CONTAINER')
sas_token = os.getenv('SAS_TOKEN')
relative_path = os.getenv('RELATIVE_PATH')

service_client = DataLakeServiceClient(account_url=f"https://{account_name}.dfs.core.windows.net", credential=sas_token)

file_system_client = service_client.get_file_system_client(container)


dataframes = []
paths = file_system_client.get_paths(path=relative_path) 
for path in paths:
    file_path = path.name  # Ensure you are using the correct file path from the directory listing
    print(f"Attempting to download: {file_path}")
    
    try:
        file_client = file_system_client.get_file_client(file_path)
        download = file_client.download_file()
        downloaded_bytes = download.readall()
        print(f"Successfully downloaded: {file_path}")
        if file_path.endswith(".xlsx"):
            df = pd.read_excel(BytesIO(downloaded_bytes), engine='openpyxl',skiprows=3)
        elif file_path.endswith(".xls"):
            df = pd.read_excel(BytesIO(downloaded_bytes), engine='xlrd',skiprows=3)
        
        # Convert the 'Session' column to numeric, forcing errors to NaN
        df['Session'] = pd.to_numeric(df['Session'], errors='coerce')
            
        # Filter out rows where 'Session' is NaN (non-numeric)
        df = df.dropna(subset=['Session'])

        dataframes.append(df)
        print(f"Successfully downloaded and read: {file_path}")
    except Exception as e:
        print(f"Error downloading {file_path}: {str(e)}")

if dataframes:
    combined_df = pd.concat(dataframes, ignore_index=True)
    for col in combined_df.columns:
        combined_df[col] = combined_df[col].astype(str)
    combined_df.rename(columns=lambda x: x.strip().replace(' ', '_').replace('.', '').replace('/', '_'), inplace=True)


    # Save the combined DataFrame as a Parquet file
    parquet_file_path = "combined_data.parquet"
    combined_df.to_parquet(parquet_file_path, engine='pyarrow')
    print(f"Successfully saved combined DataFrame to '{parquet_file_path}'")
else:
    print("No Excel files found to process.")
# Out:
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Aug 01 2023- Aug 20 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Aug 01 2023- Aug 20 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Aug 01 2023- Aug 20 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Aug 20 2023- Aug 31 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Aug 20 2023- Aug 31 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Aug 20 2023- Aug 31 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary July 01 2023-July 20 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary July 01 2023-July 20 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary July 01 2023-July 20 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary July 20 2023- Aug 01.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary July 20 2023- Aug 01.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary July 20 2023- Aug 01.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Nov 20 2023 - Nov 30 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Nov 20 2023 - Nov 30 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Nov 20 2023 - Nov 30 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Nov 30 2023 - Dec 21 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Nov 30 2023 - Dec 21 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Nov 30 2023 - Dec 21 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 01 2023 - Oct 20 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 01 2023 - Oct 20 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 01 2023 - Oct 20 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 20 2023 - Oct 31 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 20 2023 - Oct 31 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 20 2023 - Oct 31 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 31 2023 - Nov 20 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 31 2023 - Nov 20 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Oct 31 2023 - Nov 20 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Sept 01 2023 - Sept 20 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Sept 01 2023 - Sept 20 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Sept 01 2023 - Sept 20 2023.xls
# Attempting to download: deltalake/PassportIQ/bronze/CASTransactionSummary Sept 20 2023 - Sept 30 2023.xls
# Successfully downloaded: deltalake/PassportIQ/bronze/CASTransactionSummary Sept 20 2023 - Sept 30 2023.xls
# Successfully downloaded and read: deltalake/PassportIQ/bronze/CASTransactionSummary Sept 20 2023 - Sept 30 2023.xls
# Successfully saved combined DataFrame to 'combined_data.parquet'
